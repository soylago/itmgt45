# %%
Results:
{'savings': {'item_index': 1,
             'results': [{'passed': False,
                          'method': 'EXACT',
                          'expected': 5800,
                          'actual': 0.0},
                         {'passed': False,
                          'method': 'EXACT',
                          'expected': 126876898,
                          'actual': 0.0},
                         {'passed': False,
                          'method': 'EXACT',
                          'expected': 6540232,
                          'actual': 0.49999999813735485},
                         {'passed': False,
                          'method': 'EXACT',
                          'expected': 35700,
                          'actual': 0.0},
                         {'passed': False,
                          'method': 'EXACT',
                          'expected': 17392374,
                          'actual': 0.5}],
             'score': 0},
 'material_waste': {'item_index': 2,
                    'results': [{'passed': False,
                                 'method': 'EXACT',
                                 'expected': '85kg',
                                 'actual': None},
                                {'passed': False,
                                 'method': 'EXACT',
                                 'expected': '1lbs',
                                 'actual': None},
                                {'passed': False,
                                 'method': 'EXACT',
                                 'expected': '2units',
                                 'actual': None},
                                {'passed': False,
                                 'method': 'EXACT',
                                 'expected': '0items',
                                 'actual': None},
                                {'passed': False,
                                 'method': 'EXACT',
                                 'expected': '6oz',
                                 'actual': None}],
                    'score': 0},
 'interest': {'item_index': 3,
              'results': [{'passed': True,
                           'method': 'EXACT',
                           'expected': 13500,
                           'actual': 13500.0},
                          {'passed': False,
                           'method': 'EXACT',
                           'expected': 63343501,
                           'actual': 63343501.21},
                          {'passed': False,
                           'method': 'EXACT',
                           'expected': 111195332,
                           'actual': 111195332.6},
                          {'passed': True,
                           'method': 'EXACT',
                           'expected': 5450,
                           'actual': 5450.0},
                          {'passed': True,
                           'method': 'EXACT',
                           'expected': 15000,
                           'actual': 15000.0}],
              'score': 1},
 'body_mass_index': {'item_index': 4,
                     'results': [{'passed': True,
                                  'method': 'APPROXIMATE_FLOAT',
                                  'expected': 14.345903095989632,
                                  'actual': 14.348301374768427},
                                 {'passed': True,
                                  'method': 'APPROXIMATE_FLOAT',
                                  'expected': 15.33910289374809,
                                  'actual': 15.341667210871224},
                                 {'passed': True,
                                  'method': 'APPROXIMATE_FLOAT',
                                  'expected': 16.271973419062316,
                                  'actual': 16.27469368897345},
                                 {'passed': True,
                                  'method': 'APPROXIMATE_FLOAT',
                                  'expected': 26.949615480827173,
                                  'actual': 26.95412078735768},
                                 {'passed': True,
                                  'method': 'APPROXIMATE_FLOAT',
                                  'expected': 28.096864442267552,
                                  'actual': 28.10156154033741}],
                     'score': 3}}
Total Score:  4
------------------------------
Comments:

+1 for #3, answer is fine.

#2 needs to return a value, not just print it.

#1 calculates the wrong answer.

Resubmission allowed

# %%
'''Module 2: Individual Programming Assignment 1

Useful Business Calculations

This assignment covers your basic proficiency with Python.
'''
import math
def savings(gross_pay, tax_rate, expenses):
    '''Savings.
    2 points.

    This function calculates the money remaining
        for an employee after taxes and expenses.
    
    To get the take-home pay of an employee, we will
        follow the following process:
        1. Apply the tax rate to the gross pay of the employee; round down
        2. Subtract the expenses from the after-tax pay of the employee

    Parameters
    ----------
    gross_pay: int
        the gross pay of an employee for a certain time period, expressed in centavos
    tax_rate: float
        the tax rate for a certain time period, expressed as a number between 0 and 1 (e.g., 0.12)
    expenses: int
        the expenses of an employee for a certain time period, expressed in centavos

    Returns
    -------
    int
        the number of centavos remaining from an employee's pay after taxes and expenses
    '''
    # Replace `pass` with your code. 
    # Stay within the function. Only use the parameters as input. The function should return your answer.
    takehomepay = (gross_pay * tax_rate) - expenses
    takehomepay1 = math.floor(takehomepay)
    centavos =  takehomepay - takehomepay1
    return centavos

def material_waste(total_material, material_units, num_jobs, job_consumption):
    '''Material Waste.
    2 points.

    This function calculates how much material input will be wasted
        after running a certain number of jobs that consume
        a set amount of material.

    To get the waste of a set of jobs:
        1. Multiply the number of jobs by the material consumption per job.
        2. Subtract the total material consumed from the total material available.

    The users of this function also want you to format the output as a string, annotated with the
        units in which the material is expressed. Do not add a space between the number and the unit.

    Parameters
    ----------
    total_material: int
        the total material available
    material_units: str
        the units used to express a quantity of the material (e.g., "kg", "L", etc.)
    num_jobs: int
        the number of jobs to run
    job_consumption: int
        the amount of material consumed per job

    Returns
    -------
    str
        the amount of remaining material expressed with its unit (e.g., "10kg").
    '''
    # Replace `pass` with your code. 
    # Stay within the function. Only use the parameters as input. The function should return your answer.
    remaining_material1 = (total_material - (num_jobs * job_consumption))
    remaining_material_str = str(remaining_material1)
    final_material = remaining_material_str + material_units
    print(final_material)

def interest(principal, rate, periods):
    '''Interest.
    3 points.

    This function calculates the final value of an investment after
        gaining simple interest over a number of periods.

    To calculate simple interest, simply multiply the principal to the quantity (rate * time). 
        Add this amount to the principal to get the final value.

    Round down the final amount.

    Parameters
    ----------
    principal: int
        the principal (i.e., starting) amount invested, expressed in centavos
    rate: float
        the interest rate per period, expressed as a decimal representation of a percentage (e.g., 3% is 0.03)
    periods: int
        the number of periods invested

    Returns
    -------
    int
        the final value of the investment
    '''
    # Replace `pass` with your code. 
    # Stay within the function. Only use the parameters as input. The function should return your answer.
    finalvalue = principal + (principal * rate * periods)
    finalvalue1 = int(finalvalue)
    return finalvalue

def body_mass_index(weight, height):
    '''Body Mass Index.
    3 points.

    This function calculates the body mass index (BMI) of a person
        given their weight and height.

    The formula for BMI is: kg / (m ^ 2)
        (i.e., kilograms over meters squared)

    Unfortunately, the users of this function use the imperial system.
        You will need to first convert their arguments to the metric system.
    
    Parameters
    ----------
    weight: float
        the weight of the person, in pounds
    height: list
        the height of the person, expressed as a list of two integers.
        the first integer is the foot component of their height.
        the second integer is the inches component of their height.
        for example, 5'10" would be passed as [5, 10].

    Returns
    -------
    float
        the BMI of the person.
    '''
    # Replace `pass` with your code. 
    # Stay within the function. Only use the parameters as input. The function should return your answer.
    weight1 = weight * 0.45359237
    height1 = ((height[0] * 12) + height[1]) / 39.37
    bmi = weight1 / (height1 ** 2)
    return (bmi)

# %%
body_mass_index(135, [5, 1])
# Out:
# 25.507662884733445
